# %% [markdown]
# # Alpamayo 1.5 Demo

# %% [markdown]
# This notebook loads example data from the NVIDIA [PhysicalAI-AV Dataset](https://huggingface.co/datasets/nvidia/PhysicalAI-Autonomous-Vehicles) and runs the Alpamayo 1.5 model, producing output trajectories and associated chain-of-causation reasoning traces.

# %%
import numpy as np
import mediapy as mp
import pandas as pd

import torch
from alpamayo1_5.models.alpamayo1_5 import Alpamayo1_5
from alpamayo1_5.load_physical_aiavdataset import load_physical_aiavdataset
from alpamayo1_5 import helper

# %% [markdown]
# ### Load model and construct data preprocessor

# %%
model = Alpamayo1_5.from_pretrained("nvidia/Alpamayo-1.5-10B", dtype=torch.bfloat16).to("cuda")
processor = helper.get_processor(model.tokenizer)
# Out:
# The model weights are not tied. Please use the `tie_weights` method before using the `infer_auto_device` function.
# Loading checkpoint shards:   0%|          | 0/5 [00:00<?, ?it/s]

# %% [markdown]
# ### Load and prepare data

# %%
clip_ids = pd.read_parquet("clip_ids.parquet")["clip_id"].tolist()
clip_id = clip_ids[774]

data = torch.load(f"data/{clip_id}.pt", map_location=torch.device("cuda:0"))

messages = helper.create_message(
    data["image_frames"].flatten(0, 1),
    camera_indices=data["camera_indices"],
)

inputs = processor.apply_chat_template(
    messages,
    tokenize=True,
    add_generation_prompt=False,
    continue_final_message=True,
    return_dict=True,
    return_tensors="pt",
)
print("seq length:", inputs.input_ids.shape)
model_inputs = {
    "tokenized_data": inputs,
    "ego_history_xyz": data["ego_history_xyz"],
    "ego_history_rot": data["ego_history_rot"],
}
model_inputs = helper.to_device(model_inputs, "cuda")
# Out:
# seq length: torch.Size([1, 3086])

# %% [markdown]
# ### Model inference

# %%
torch.cuda.manual_seed_all(42)
with torch.autocast("cuda", dtype=torch.bfloat16):
    pred_xyz, pred_rot, extra = model.sample_trajectories_from_data_with_vlm_rollout(
        data=model_inputs,
        top_p=0.98,
        temperature=0.6,
        num_traj_samples=1,
        max_generation_length=256,
        return_extra=True,
    )

print("Chain-of-Causation (per trajectory):\n", extra["cot"][0])
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[4], line 3
#       1 torch.cuda.manual_seed_all(42)
#       2 with torch.autocast("cuda", dtype=torch.bfloat16):
# ----> 3     pred_xyz, pred_rot, extra = model.sample_trajectories_from_data_with_vlm_rollout(
#       4         data=model_inputs,
#       5         top_p=0.98,
#       6         temperature=0.6,
#       7         num_traj_samples=1,
#       8         max_generation_length=256,
#       9         return_extra=True,
#      10     )
#      12 print("Chain-of-Causation (per trajectory):\n", extra["cot"][0])
#
# File ~/alpamayo1.5/src/alpamayo1_5/models/alpamayo1_5.py:364, in Alpamayo1_5.sample_trajectories_from_data_with_vlm_rollout(self, data, top_p, top_k, temperature, num_traj_samples, num_traj_sets, diffusion_kwargs, *args, **kwargs)
#     361 if diffusion_kwargs is None:
#     362     diffusion_kwargs = {}
# --> 364 sampled_action = self.diffusion.sample(
#     365     batch_size=total_batch,
#     366     step_fn=step_fn,
#     367     device=device,
#     368     return_all_steps=False,
#     369     **diffusion_kwargs,
#     370 )
#     372 # Repeat history to align with num_traj_samples
#     373 hist_xyz_rep = einops.repeat(
#     374     ego_history_xyz[:, -1], "b ... -> (b n) ...", n=n_samples_total
#     375 )
#
# File ~/alpamayo1.5/a1_5_venv/lib/python3.12/site-packages/torch/utils/_contextlib.py:120, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     117 @functools.wraps(func)
#     118 def decorate_context(*args, **kwargs):
#     119     with ctx_factory():
# --> 120         return func(*args, **kwargs)
#
# File ~/alpamayo1.5/src/alpamayo1_5/diffusion/flow_matching.py:100, in FlowMatching.sample(self, batch_size, step_fn, unguided_step_fn, device, return_all_steps, inference_step, int_method, use_classifier_free_guidance, inference_guidance_weight, temperature, *args, **kwargs)
#      98     raise ValueError("unguided_step_fn is required when using classifier free guidance")
#      99 if int_method == "euler":
# --> 100     return self._euler(
#     101         batch_size=batch_size,
#     102         step_fn=step_fn,
#     103         unguided_step_fn=unguided_step_fn,
#     104         device=device,
#     105         return_all_steps=return_all_steps,
#     106         inference_step=inference_step,
#     107         inference_guidance_weight=inference_guidance_weight,
#     108         use_classifier_free_guidance=use_classifier_free_guidance,
#     109         temperature=temperature,
#     110     )
#     111 else:
#     112     raise ValueError(f"Invalid integration method: {int_method}")
#
# File ~/alpamayo1.5/src/alpamayo1_5/diffusion/flow_matching.py:190, in FlowMatching._euler(self, batch_size, step_fn, unguided_step_fn, device, return_all_steps, inference_step, inference_guidance_weight, use_classifier_free_guidance, temperature)
#     182     v = self._guided_v(
#     183         step_fn=step_fn,
#     184         x=x,
#    (...)    187         inference_guidance_weight=inference_guidance_weight,
#     188     )
#     189 else:
# --> 190     v = step_fn(x=x, t=t_start)
#     191 x = x + dt * v
#     192 if return_all_steps:
#
# File ~/alpamayo1.5/src/alpamayo1_5/models/alpamayo1_5.py:342, in Alpamayo1_5.sample_trajectories_from_data_with_vlm_rollout.<locals>.step_fn(x, t)
#     339     future_token_embeds = future_token_embeds.view(b_star, n_diffusion_tokens, -1)
#     341 # Run expert with cached prefill, only on the future tokens
# --> 342 expert_out_base = self.expert(
#     343     inputs_embeds=future_token_embeds,
#     344     position_ids=position_ids,
#     345     past_key_values=prompt_cache,
#     346     attention_mask=attention_mask,
#     347     use_cache=True,
#     348     **forward_kwargs,
#     349 )
#     350 # crop the prompt cache to remove the newly added tokens
#     351 prompt_cache.crop(prefill_seq_len)
#
# File ~/alpamayo1.5/a1_5_venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File ~/alpamayo1.5/a1_5_venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File ~/alpamayo1.5/a1_5_venv/lib/python3.12/site-packages/accelerate/hooks.py:175, in add_hook_to_module.<locals>.new_forward(module, *args, **kwargs)
#     173         output = module._old_forward(*args, **kwargs)
#     174 else:
# --> 175     output = module._old_forward(*args, **kwargs)
#     176 return module._hf_hook.post_forward(module, output)
#
# File ~/alpamayo1.5/a1_5_venv/lib/python3.12/site-packages/transformers/utils/generic.py:1064, in check_model_inputs.<locals>.wrapper(self, *args, **kwargs)
#    1061                 monkey_patched_layers.append((module, original_forward))
#    1063 try:
# -> 1064     outputs = func(self, *args, **kwargs)
#    1065 except TypeError as original_exception:
#    1066     # If we get a TypeError, it's possible that the model is not receiving the recordable kwargs correctly.
#    1067     # Get a TypeError even after removing the recordable kwargs -> re-raise the original exception
#    1068     # Otherwise -> we're probably missing `**kwargs` in the decorated function
#    1069     kwargs_without_recordable = {k: v for k, v in kwargs.items() if k not in recordable_keys}
#
# File ~/alpamayo1.5/a1_5_venv/lib/python3.12/site-packages/transformers/models/qwen3_vl/modeling_qwen3_vl.py:850, in Qwen3VLTextModel.forward(self, input_ids, attention_mask, position_ids, past_key_values, inputs_embeds, use_cache, cache_position, visual_pos_masks, deepstack_visual_embeds, **kwargs)
#     848 # decoder layers
#     849 for layer_idx, decoder_layer in enumerate(self.layers):
# --> 850     layer_outputs = decoder_layer(
#     851         hidden_states,
#     852         attention_mask=attention_mask,
#     853         position_ids=text_position_ids,
#     854         past_key_values=past_key_values,
#     855         cache_position=cache_position,
#     856         position_embeddings=position_embeddings,
#     857         **kwargs,
#     858     )
#     859     hidden_states = layer_outputs
#     861     # add visual features to the hidden states of first several layers
#
# File ~/alpamayo1.5/a1_5_venv/lib/python3.12/site-packages/transformers/modeling_layers.py:94, in GradientCheckpointingLayer.__call__(self, *args, **kwargs)
#      91         logger.warning_once(message)
#      93     return self._gradient_checkpointing_func(partial(super().__call__, **kwargs), *args)
# ---> 94 return super().__call__(*args, **kwargs)
#
# File ~/alpamayo1.5/a1_5_venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File ~/alpamayo1.5/a1_5_venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File ~/alpamayo1.5/a1_5_venv/lib/python3.12/site-packages/accelerate/hooks.py:175, in add_hook_to_module.<locals>.new_forward(module, *args, **kwargs)
#     173         output = module._old_forward(*args, **kwargs)
#     174 else:
# --> 175     output = module._old_forward(*args, **kwargs)
#     176 return module._hf_hook.post_forward(module, output)
#
# File ~/alpamayo1.5/a1_5_venv/lib/python3.12/site-packages/transformers/utils/deprecation.py:172, in deprecate_kwarg.<locals>.wrapper.<locals>.wrapped_func(*args, **kwargs)
#     168 elif minimum_action in (Action.NOTIFY, Action.NOTIFY_ALWAYS) and not is_torchdynamo_compiling():
#     169     # DeprecationWarning is ignored by default, so we use FutureWarning instead
#     170     warnings.warn(message, FutureWarning, stacklevel=2)
# --> 172 return func(*args, **kwargs)
#
# File ~/alpamayo1.5/a1_5_venv/lib/python3.12/site-packages/transformers/models/qwen3_vl/modeling_qwen3_vl.py:502, in Qwen3VLTextDecoderLayer.forward(self, hidden_states, position_embeddings, attention_mask, position_ids, past_key_values, use_cache, cache_position, **kwargs)
#     500 hidden_states = self.input_layernorm(hidden_states)
#     501 # Self Attention
# --> 502 hidden_states, _ = self.self_attn(
#     503     hidden_states=hidden_states,
#     504     attention_mask=attention_mask,
#     505     position_ids=position_ids,
#     506     past_key_values=past_key_values,
#     507     use_cache=use_cache,
#     508     cache_position=cache_position,
#     509     position_embeddings=position_embeddings,
#     510     **kwargs,
#     511 )
#     512 hidden_states = residual + hidden_states
#     514 # Fully Connected
#
# File ~/alpamayo1.5/a1_5_venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File ~/alpamayo1.5/a1_5_venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File ~/alpamayo1.5/a1_5_venv/lib/python3.12/site-packages/accelerate/hooks.py:175, in add_hook_to_module.<locals>.new_forward(module, *args, **kwargs)
#     173         output = module._old_forward(*args, **kwargs)
#     174 else:
# --> 175     output = module._old_forward(*args, **kwargs)
#     176 return module._hf_hook.post_forward(module, output)
#
# File ~/alpamayo1.5/a1_5_venv/lib/python3.12/site-packages/transformers/utils/deprecation.py:172, in deprecate_kwarg.<locals>.wrapper.<locals>.wrapped_func(*args, **kwargs)
#     168 elif minimum_action in (Action.NOTIFY, Action.NOTIFY_ALWAYS) and not is_torchdynamo_compiling():
#     169     # DeprecationWarning is ignored by default, so we use FutureWarning instead
#     170     warnings.warn(message, FutureWarning, stacklevel=2)
# --> 172 return func(*args, **kwargs)
#
# File ~/alpamayo1.5/a1_5_venv/lib/python3.12/site-packages/transformers/models/qwen3_vl/modeling_qwen3_vl.py:438, in Qwen3VLTextAttention.forward(self, hidden_states, position_embeddings, attention_mask, past_key_values, cache_position, **kwargs)
#     435 if past_key_values is not None:
#     436     # sin and cos are specific to RoPE models; cache_position needed for the static cache
#     437     cache_kwargs = {"sin": sin, "cos": cos, "cache_position": cache_position}
# --> 438     key_states, value_states = past_key_values.update(key_states, value_states, self.layer_idx, cache_kwargs)
#     440 attention_interface: Callable = eager_attention_forward
#     441 if self.config._attn_implementation != "eager":
#
# File ~/alpamayo1.5/a1_5_venv/lib/python3.12/site-packages/transformers/cache_utils.py:776, in Cache.update(self, key_states, value_states, layer_idx, cache_kwargs)
#     773     torch.cuda.default_stream(key_states.device).wait_stream(self.prefetch_stream)
#     774     self.prefetch(layer_idx + 1, self.only_non_sliding)
# --> 776 keys, values = self.layers[layer_idx].update(key_states, value_states, cache_kwargs)
#     778 if self.offloading:
#     779     self.offload(layer_idx, self.only_non_sliding)
#
# File ~/alpamayo1.5/a1_5_venv/lib/python3.12/site-packages/transformers/cache_utils.py:119, in DynamicLayer.update(self, key_states, value_states, cache_kwargs)
#     116 if not self.is_initialized:
#     117     self.lazy_initialization(key_states)
# --> 119 self.keys = torch.cat([self.keys, key_states], dim=-2)
#     120 self.values = torch.cat([self.values, value_states], dim=-2)
#     121 return self.keys, self.values
#
# RuntimeError: Expected all tensors to be on the same device, but got tensors is on cuda:1, different from other tensors on cuda:0 (when checking argument in method wrapper_CUDA_cat)

# %% [markdown]
# ## Visualizing data and results

# %%
mp.show_images(data["image_frames"].flatten(0, 1).permute(0, 2, 3, 1), columns=4, width=200)

# %%
import matplotlib.pyplot as plt

for i in range(pred_xyz.shape[2]):
    pred_xy = pred_xyz.cpu()[0, 0, i, :, :2].T.numpy()
    gt_xy = data["ego_future_xyz"].cpu()[0, 0, :, :2].T.numpy()
    plt.plot(pred_xy[0], pred_xy[1], "o-", label=f"Predicted Trajectory #{i + 1}")
plt.plot(gt_xy[0], gt_xy[1], "r-", label="Ground Truth Trajectory")
plt.xlabel("x (m)")
plt.ylabel("y (m)")
plt.legend(loc="best")
plt.axis("equal")

# %%
pred_xy_all = pred_xyz.cpu().numpy()[0, 0, :, :, :2].transpose(0, 2, 1)
diff = np.linalg.norm(pred_xy_all - gt_xy[None, ...], axis=1).mean(-1)
print("minADE:", diff.min(), "meters")
